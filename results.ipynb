# %%
import librosa
import os
import IPython
import numpy as np

from wavelet_filter import Wavelet_Filter
from utils import plot_original_vs_filtered, calc_snr, plot_spectrogram

# %%
start = 600000
end = 2500000

data_path = f'{os.getcwd()}/data/1800_convo.wav'
signal, sr = librosa.load(data_path)
signal += np.random.uniform(0, 0.2 ,len(signal)) * np.random.normal(0, 0.2, len(signal))
#IPython.display.Audio(signal[start:end], rate = sr)

# %%
wavelet_filter = Wavelet_Filter(threshold="soft", wavelet="db2", 
                                level = 1, mode = "per", x=signal)
reconstr = wavelet_filter._filter(scaling_factor=0.5, universal=True, operation="median")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File pywt/_extensions/_pywt.pyx:123, in pywt._extensions._pywt._Modes.from_object()
#
# File pywt/_extensions/_pywt.pyx:136, in pywt._extensions._pywt._Modes.__getattr__()
#
# AttributeError: '_Modes' object has no attribute 'asym'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 wavelet_filter = Wavelet_Filter(threshold="soft", wavelet="db2",
#       2                                 level = 1, mode = "asym", x=signal)
# ----> 3 reconstr = wavelet_filter._filter(scaling_factor=0.5, universal=True, operation="median")
#
# File ~/Documents/speech_enhancement_filters/wavelet_filter.py:49, in Wavelet_Filter._filter(self, scaling_factor, universal, operation)
#      45 def _filter(self, scaling_factor: float, universal: bool, operation: str):
#      46     """Performs filtering based off of universal or per-scale thresholds. The
#      47     former is based off the AWGN (Additive White Gaussian Noise) assumption. The latter
#      48     is better suited when dealing with correlated noise"""
# ---> 49     coeffs = pywt.wavedec(self.x, wavelet = self.wavelet, mode= self.mode)
#      50     cA = coeffs[0] # cA_n
#      51     cDs = coeffs[1:] # cD_n, cD_n-1, …, cD2, cD1
#
# File ~/Documents/speech_enhancement_filters/.venv/lib/python3.11/site-packages/pywt/_multilevel.py:103, in wavedec(data, wavelet, mode, level, axis)
#     101 a = data
#     102 for i in range(level):
# --> 103     a, d = dwt(a, wavelet, mode, axis)
#     104     coeffs_list.append(d)
#     106 coeffs_list.append(a)
#
# File ~/Documents/speech_enhancement_filters/.venv/lib/python3.11/site-packages/pywt/_dwt.py:173, in dwt(data, wavelet, mode, axis)
#     171 dt = _check_dtype(data)
#     172 data = np.asarray(data, dtype=dt, order='C')
# --> 173 mode = Modes.from_object(mode)
#     174 wavelet = _as_wavelet(wavelet)
#     176 if axis < 0:
#
# File pywt/_extensions/_pywt.pyx:125, in pywt._extensions._pywt._Modes.from_object()
#
# ValueError: Unknown mode name 'asym'.

# %%
#IPython.display.Audio(reconstr[start:end], rate = sr)

# %%
plot_original_vs_filtered(x = signal, x_hat = reconstr, start = start, end = end, sr=sr)

# %%
plot_spectrogram(audio_signal=signal, sr = sr, title = 'Plot of Original Signal',
                 out_path=f'{os.getcwd()}/plots')
plot_spectrogram(audio_signal=reconstr, sr = sr, title = 'Plot of Filtered Signal',
                 out_path=f'{os.getcwd()}/plots')

# %%
display(calc_snr(x = signal, x_hat=reconstr))
# Out:
# np.float64(10.922926591891244)
